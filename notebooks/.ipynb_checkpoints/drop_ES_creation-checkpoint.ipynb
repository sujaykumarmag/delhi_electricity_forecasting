# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../main/ndlc_psp_final.csv")

# %%
df
# Out:
#       Unnamed: 0 Date (DD/MM/YYYY)  Max.Demand met during the day (MW)  \
# 0              0            1/4/13                                2776
# 1              1            2/4/13                                3034
# 2              2            3/4/13                                2991
# 3              3            4/4/13                                3125
# 4              4            5/4/13                                3160
# ...          ...               ...                                 ...
# 3635        3635          27/05/23                                5051
# 3636        3636          28/05/23                                4780
# 3637        3637          29/05/23                                4782
# 3638        3638          30/05/23                                4871
# 3639        3639          31/05/23                                4462
#
#       Shortage during maximum Demand (MW)  Energy Met (MU)  \
# ...

# %%
df = df.drop("Unnamed: 0",axis=1)

# %%
df.dtypes
# Out:
# Date (DD/MM/YYYY)                       object
# Max.Demand met during the day (MW)       int64
# Shortage during maximum Demand (MW)    float64
# Energy Met (MU)                        float64
# Drawal Schedule\n(MU)                  float64
# OD(+)/UD(-) (MU)                       float64
# Max OD (MW)                            float64
# Energy Shortage (MU)                   float64
# dtype: object

# %%
df
# Out:
#      Date (DD/MM/YYYY)  Max.Demand met during the day (MW)  \
# 0               1/4/13                                2776
# 1               2/4/13                                3034
# 2               3/4/13                                2991
# 3               4/4/13                                3125
# 4               5/4/13                                3160
# ...                ...                                 ...
# 3635          27/05/23                                5051
# 3636          28/05/23                                4780
# 3637          29/05/23                                4782
# 3638          30/05/23                                4871
# 3639          31/05/23                                4462
#
#       Shortage during maximum Demand (MW)  Energy Met (MU)  \
# 0                                     0.0             56.1
# 1                                     0.0             61.0
# 2                                     0.0             62.1
# ...

# %%
cols = df.columns
for i in cols:
    print(i,'-------------------',df[i].isnull().sum())
# Out:
# Date (DD/MM/YYYY) ------------------- 0
# Max.Demand met during the day (MW) ------------------- 0
# Shortage during maximum Demand (MW) ------------------- 0
# Energy Met (MU) ------------------- 0
# Drawal Schedule
# (MU) ------------------- 0
# OD(+)/UD(-) (MU) ------------------- 0
# Max OD (MW) ------------------- 2
# Energy Shortage (MU) ------------------- 1456

# %%
df = df[cols[0:7]]

# %%
df = df.dropna(axis=0)

# %%
cols = df.columns
for i in cols:
    print(i,'-------------------',df[i].isnull().sum())
# Out:
# Date (DD/MM/YYYY) ------------------- 0
# Max.Demand met during the day (MW) ------------------- 0
# Shortage during maximum Demand (MW) ------------------- 0
# Energy Met (MU) ------------------- 0
# Drawal Schedule
# (MU) ------------------- 0
# OD(+)/UD(-) (MU) ------------------- 0
# Max OD (MW) ------------------- 0

# %%
df.to_csv("../main/sub_data/multi_variant/ndlc_psp_dropES.csv")
