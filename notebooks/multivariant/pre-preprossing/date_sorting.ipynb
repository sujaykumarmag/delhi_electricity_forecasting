# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../main/ndlc_psp_pre.csv")

# %%
df
# Out:
#      Date (DD/MM/YYYY) Max.Demand met during the day (MW)  \
# 0             21/12/13                            3381.00
# 1             15/08/15                            4862.00
# 2             16/11/14                            2934.00
# 3             14/09/22                            5947.00
# 4             23/03/15                            2880.00
# ...                ...                                ...
# 3635          15/06/21                            5771.00
# 3636          14/07/16                            5327.00
# 3637          15/08/18                            5777.00
# 3638          16/11/19                            3588.00
# 3639          23/03/18                            3523.00
#
#      Shortage during maximum Demand (MW) Energy Met (MU)  \
# 0                                   0.00           60.80
# 1                                   0.00          104.10
# 2                                  15.00           54.90
# ...

# %%
df = df[["Date (DD/MM/YYYY)","Max.Demand met during the day (MW)",
         "Shortage during maximum Demand (MW)","Energy Met (MU)",
         "Drawal Schedule\n(MU)","OD(+)/UD(-) (MU)","Max OD (MW)",
         "Energy Shortage (MU)"]]

# %%
df
# Out:
#      Date (DD/MM/YYYY) Max.Demand met during the day (MW)  \
# 0             21/12/13                            3381.00
# 1             15/08/15                            4862.00
# 2             16/11/14                            2934.00
# 3             14/09/22                            5947.00
# 4             23/03/15                            2880.00
# ...                ...                                ...
# 3635          15/06/21                            5771.00
# 3636          14/07/16                            5327.00
# 3637          15/08/18                            5777.00
# 3638          16/11/19                            3588.00
# 3639          23/03/18                            3523.00
#
#      Shortage during maximum Demand (MW) Energy Met (MU)  \
# 0                                   0.00           60.80
# 1                                   0.00          104.10
# 2                                  15.00           54.90
# ...

# %%
df['Date (DD/MM/YYYY)'] = pd.to_datetime(df["Date (DD/MM/YYYY)"], format='%d/%m/%y')
df_sorted = df.sort_values('Date (DD/MM/YYYY)')
df_sorted = df_sorted.reset_index(drop=True)
# Out:
# /var/folders/l2/_mks1sd56yjdxq9514qt1fnh0000gn/T/ipykernel_3084/1066552671.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date (DD/MM/YYYY)'] = pd.to_datetime(df["Date (DD/MM/YYYY)"], format='%d/%m/%y')

# %%
df_sorted
# Out:
#      Date (DD/MM/YYYY) Max.Demand met during the day (MW)  \
# 0           2013-04-01                            2776.00
# 1           2013-04-02                            3034.00
# 2           2013-04-03                            2991.00
# 3           2013-04-04                            3125.00
# 4           2013-04-05                            3160.00
# ...                ...                                ...
# 3635        2023-05-27                            5051.00
# 3636        2023-05-28                            4780.00
# 3637        2023-05-29                            4782.00
# 3638        2023-05-30                            4871.00
# 3639        2023-05-31                            4462.00
#
#      Shortage during maximum Demand (MW) Energy Met (MU)  \
# 0                                   0.00           56.10
# 1                                   0.00           61.00
# 2                                   0.00           62.10
# ...

# %%
# Save it as .csv
df_sorted.to_csv("../main/ndlc_psp_post.csv")

# %%
df_sorted["Max.Demand met during the day (MW)"].isnull().sum()
# Out:
# 1
