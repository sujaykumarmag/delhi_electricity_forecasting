# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv("../../../main/ndlc_psp_final.csv")

# %%
df
# Out:
#       Unnamed: 0 Date (DD/MM/YYYY)  Max.Demand met during the day (MW)  \
# 0              0            1/4/13                                2776
# 1              1            2/4/13                                3034
# 2              2            3/4/13                                2991
# 3              3            4/4/13                                3125
# 4              4            5/4/13                                3160
# ...          ...               ...                                 ...
# 3635        3635          27/05/23                                5051
# 3636        3636          28/05/23                                4780
# 3637        3637          29/05/23                                4782
# 3638        3638          30/05/23                                4871
# 3639        3639          31/05/23                                4462
#
#       Shortage during maximum Demand (MW)  Energy Met (MU)  \
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0                               int64
# Date (DD/MM/YYYY)                       object
# Max.Demand met during the day (MW)       int64
# Shortage during maximum Demand (MW)    float64
# Energy Met (MU)                        float64
# Drawal Schedule\n(MU)                  float64
# OD(+)/UD(-) (MU)                       float64
# Max OD (MW)                            float64
# Energy Shortage (MU)                   float64
# dtype: object

# %%
cols = df.columns
for i in cols:
    print(i,'-------------------',df[i].isnull().sum())
# Out:
# Unnamed: 0 ------------------- 0
# Date (DD/MM/YYYY) ------------------- 0
# Max.Demand met during the day (MW) ------------------- 0
# Shortage during maximum Demand (MW) ------------------- 0
# Energy Met (MU) ------------------- 0
# Drawal Schedule
# (MU) ------------------- 0
# OD(+)/UD(-) (MU) ------------------- 0
# Max OD (MW) ------------------- 2
# Energy Shortage (MU) ------------------- 1456

# %%
df = df.dropna(subset=['Max OD (MW)'])

# %%
def regression_imputation(dataframe, variable):
    
    # Create a copy of the DataFrame
    df_copy = dataframe.copy()
    df_copy = df_copy.drop(["Date (DD/MM/YYYY)","Unnamed: 0"],axis=1)
    train_data = df_copy[df_copy[variable].notnull()]
    
    # Create a DataFrame with missing values for the target variable
    test_data = df_copy[df_copy[variable].isnull()]
    
    # Separate features and target variables for training and testing data
    X_train = train_data.drop(variable, axis=1)
    y_train = train_data[variable]
    X_test = test_data.drop(variable, axis=1)
    
    # Build a linear regression model
    regression_model = LinearRegression()
    
    # Fit the model on the training data
    regression_model.fit(X_train, y_train)
    
    # Predict missing values based on the model
    imputed_values = regression_model.predict(X_test)
    
    # Assign the predicted values to the missing values in the DataFrame
    dataframe.loc[dataframe[variable].isnull(), variable] = imputed_values

# %%
regression_imputation(df, "Energy Shortage (MU)")

# %%
df
# Out:
#       Unnamed: 0 Date (DD/MM/YYYY)  Max.Demand met during the day (MW)  \
# 0              0            1/4/13                                2776
# 1              1            2/4/13                                3034
# 2              2            3/4/13                                2991
# 3              3            4/4/13                                3125
# 4              4            5/4/13                                3160
# ...          ...               ...                                 ...
# 3635        3635          27/05/23                                5051
# 3636        3636          28/05/23                                4780
# 3637        3637          29/05/23                                4782
# 3638        3638          30/05/23                                4871
# 3639        3639          31/05/23                                4462
#
#       Shortage during maximum Demand (MW)  Energy Met (MU)  \
# ...

# %%
df.to_csv("../../../main/sub_data/ndlc_psp_ES_regr.csv")
